# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r"D:\dataset\customer_data.csv.zip")
print(df.head())
# Out:
#    id  age  gender  income   education region loyalty_status  \
# 0   1   27    Male   40682    Bachelor   East           Gold
# 1   2   29    Male   15317     Masters   West        Regular
# 2   3   37    Male   38849    Bachelor   West         Silver
# 3   4   30    Male   11568  HighSchool  South        Regular
# 4   5   31  Female   46952     College  North        Regular
#
#   purchase_frequency  purchase_amount product_category  promotion_usage  \
# 0           frequent            18249            Books                0
# 1               rare             4557         Clothing                1
# 2               rare            11822         Clothing                0
# 3           frequent             4098             Food                0
# 4         occasional            19685         Clothing                1
#
#    satisfaction_score
# 0                   6
# 1                   6
# 2                   6
# 3                   7
# 4                   5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  100000 non-null  int64
#  1   age                 100000 non-null  int64
#  2   gender              100000 non-null  str
#  3   income              100000 non-null  int64
#  4   education           100000 non-null  str
#  5   region              100000 non-null  str
#  6   loyalty_status      100000 non-null  str
#  7   purchase_frequency  100000 non-null  str
#  8   purchase_amount     100000 non-null  int64
#  9   product_category    100000 non-null  str
#  10  promotion_usage     100000 non-null  int64
#  11  satisfaction_score  100000 non-null  int64
# dtypes: int64(6), str(6)
# memory usage: 9.2 MB

# %%
df.describe()
# Out:
#                   id            age         income  purchase_amount  \
# count  100000.000000  100000.000000  100000.000000    100000.000000
# mean    50000.500000      30.003260   27516.269880      9634.790840
# std     28867.657797       4.480535   12996.782587      4799.339449
# min         1.000000      12.000000    5000.000000      1118.000000
# 25%     25000.750000      27.000000   16271.750000      5583.000000
# 50%     50000.500000      30.000000   27584.500000      9452.000000
# 75%     75000.250000      33.000000   38747.250000     13350.000000
# max    100000.000000      49.000000   50000.000000     26204.000000
#
#        promotion_usage  satisfaction_score
# count    100000.000000       100000.000000
# mean          0.300800            5.009650
# std           0.458608            1.038714
# min           0.000000            0.000000
# 25%           0.000000            4.000000
# 50%           0.000000            5.000000
# 75%           1.000000            6.000000
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# age                   0
# gender                0
# income                0
# education             0
# region                0
# loyalty_status        0
# purchase_frequency    0
# purchase_amount       0
# product_category      0
# promotion_usage       0
# satisfaction_score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# id                    int64
# age                   int64
# gender                  str
# income                int64
# education               str
# region                  str
# loyalty_status          str
# purchase_frequency      str
# purchase_amount       int64
# product_category        str
# promotion_usage       int64
# satisfaction_score    int64
# dtype: object

# %%
df["gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df["region"].unique()
# Out:
# <StringArray>
# ['East', 'West', 'South', 'North']
# Length: 4, dtype: str

# %%
df["education"].unique()
# Out:
# <StringArray>
# ['Bachelor', 'Masters', 'HighSchool', 'College']
# Length: 4, dtype: str

# %%
df["loyalty_status"].unique()
# Out:
# <StringArray>
# ['Gold', 'Regular', 'Silver']
# Length: 3, dtype: str

# %%
df["purchase_frequency"].unique()
# Out:
# <StringArray>
# ['frequent', 'rare', 'occasional']
# Length: 3, dtype: str

# %%
df["purchase_frequency"] = df["purchase_frequency"].str.title()

# %%
engine = create_engine(
    "mysql+pymysql://root:060422@localhost:3306/customer_behaviour_project"
)
df.to_sql(
  name= "customers",
  con= engine,
  if_exists= "replace",
  index= False
 )
print("transfer_successfull")
# Out:
# transfer_successfull
